# %% [markdown]
# # Chicago Building Energy Use
# ## Data Cleaning and Exploratory Data Analysis
#
# ### Project Overview
#
# This project demonstrates a complete data cleaning and exploratory data analysis (EDA) workflow using the City of Chicago Building Energy Use dataset.
#
# The objective is to prepare the dataset for analysis by identifying and correcting data quality issues, validating the cleaned data, and exploring patterns in building energy consumption through summary statistics and visualizations.
#
# The notebook follows a structured, reproducible workflow consistent with professional data science best practices and is intended to demonstrate practical data preparation and exploratory analysis skills for a portfolio project.

# %%
import numpy as np                  # Linear algebra
import pandas as pd                 # Data processing, CSV file I/O (e.g., pd.read_csv)
import matplotlib.pyplot as plt     # Matplotlib for plotting
import seaborn as sns               # Seaborn for statistical visualization

# Configure pandas display options
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.2f}".format)

# %%
# Load the dataset
df = pd.read_csv("../data/raw/NN_Energy_Use_20260718.csv")

# %% [markdown]
# ## Initial Inspection
#
# The purpose of this section is to gain an initial understanding of the dataset before making any modifications. This includes reviewing the dataset's structure, dimensions, column names, data types, and summary statistics to identify areas that may require further investigation during the data cleaning process.

# %%
df.head()
# Out:
#   COMMUNITY AREA NAME       CENSUS BLOCK BUILDING TYPE BUILDING_SUBTYPE  \
# 0     Near North Side 170310818002021.00    Commercial       Commercial
# 1     Near North Side 170310801004004.00    Commercial       Commercial
# 2     Near North Side 170310804001003.00   Residential        Multi < 7
# 3     Near North Side 170310810005005.00    Commercial       Commercial
# 4     Near North Side 170310815002006.00    Commercial       Commercial
#
#   KWH JANUARY 2010 KWH FEBRUARY 2010 KWH MARCH 2010 KWH APRIL 2010  \
# 0              NaN               NaN            NaN            NaN
# 1          715,681           617,436        394,468        174,066
# 2            1,959             2,039          1,647          1,504
# 3              NaN               NaN            NaN            NaN
# 4        1,351,588         1,229,157        943,203        864,062
#
#   KWH MAY 2010 KWH JUNE 2010 KWH JULY 2010 KWH AUGUST 2010 KWH SEPTEMBER 2010  \
# ...

# %%
df.shape
# Out:
# (666, 73)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 666 entries, 0 to 665
# Data columns (total 73 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   COMMUNITY AREA NAME                  666 non-null    str
#  1   CENSUS BLOCK                         665 non-null    float64
#  2   BUILDING TYPE                        665 non-null    str
#  3   BUILDING_SUBTYPE                     665 non-null    str
#  4   KWH JANUARY 2010                     635 non-null    str
#  5   KWH FEBRUARY 2010                    635 non-null    str
#  6   KWH MARCH 2010                       635 non-null    str
#  7   KWH APRIL 2010                       635 non-null    str
#  8   KWH MAY 2010                         635 non-null    str
#  9   KWH JUNE 2010                        635 non-null    str
#  10  KWH JULY 2010                        635 non-null    str
# ...

# %%
df.describe()
# Out:
#             CENSUS BLOCK  AVERAGE STORIES  AVERAGE BUILDING AGE  \
# count             665.00           666.00                666.00
# mean  170311509962382.59             6.83                 48.00
# std        2196078283.62            10.40                 44.67
# min   170310713001002.00             1.00                  0.00
# 25%   170310803004000.00             1.50                  1.33
# 50%   170310812021010.00             3.00                 38.50
# 75%   170310817002029.00             6.00                 85.00
# max   170318422001079.00            74.00                134.00
#
#        AVERAGE HOUSESIZE  OCCUPIED UNITS PERCENTAGE  \
# count             666.00                     561.00
# mean                2.11                       0.86
# std                15.80                       0.15
# min                 0.00                       0.00
# 25%                 1.30                       0.82
# 50%                 1.58                       0.90
# ...
